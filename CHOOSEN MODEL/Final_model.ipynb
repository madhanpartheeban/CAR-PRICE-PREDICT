# %%
! pip install streamlit
# Out:
# Requirement already satisfied: streamlit in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (1.40.2)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: click<9,>=7.0 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from streamlit) (2.1.3)
# Requirement already satisfied: packaging<25,>=20 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from streamlit) (2.2.3)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from streamlit) (11.0.0)
# Requirement already satisfied: protobuf<6,>=3.20 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from streamlit) (5.29.0)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from streamlit) (18.1.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from streamlit) (13.9.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from streamlit) (9.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from streamlit) (4.12.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from streamlit) (6.4.1)
# Requirement already satisfied: jinja2 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from altair<6,>=4.0->streamlit) (1.15.1)
# Requirement already satisfied: colorama in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from requests<3,>=2.27->streamlit) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from requests<3,>=2.27->streamlit) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.18.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.21.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.16.0)
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score
import pickle

# %%
data = pd.read_csv(r"C:\Users\GS0864\OneDrive\Desktop\for_vs_code\CAR_PRICE_PREDICTION\EDA\Final_data.csv", index_col=0)

# %%
data.head()
# Out:
#    body type  Kilometers driven Transmission type  Number of owners  \
# 0  Hatchback             120000            Manual                 3
# 1        SUV              32706            Manual                 2
# 2  Hatchback              11949            Manual                 1
# 3      Sedan              17794            Manual                 1
# 4        SUV              60000            Manual                 1
#
#             car model  Year of manufacture     price Fuel Type  \
# 0      Maruti Celerio                 2015  400000.0    Petrol
# 1       Ford Ecosport                 2018  811000.0    Petrol
# 2          Tata Tiago                 2018  585000.0    Petrol
# 3       Hyundai Xcent                 2014  462000.0    Petrol
# 4  Maruti SX4 S Cross                 2015  790000.0    Diesel
#
#       Insurance Validity  Seats  Engine  Mileage   Color Turbo Charger  \
# 0  Third Party insurance    5.0   998.0    23.10   White            No
# 1          Comprehensive    5.0  1497.0    17.00   White            No
# 2          Comprehensive    5.0  1199.0    23.84     Red            No
# 3          Comprehensive    5.0  1197.0    19.10  Others            No
# 4  Third Party insurance    5.0  1248.0    23.65    Gray           Yes
#
#   Super Charger Steering Type  Top Speed  No of Doors  Cargo Volumn      City
# 0            No         Power      150.0            5           235  Banglore
# 1            No         Power      170.0            4           352  Banglore
# 2            No         Power      150.0            5           242  Banglore
# 3            No         Power      172.0            4           407  Banglore
# 4            No         Power      190.0            5           353  Banglore

# %%
data['City'].value_counts()
# Out:
# City
# Delhi        1471
# Hyderabad    1464
# Banglore     1463
# Chennai      1409
# Kolkata      1362
# Jaipur       1092
# Name: count, dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(1)

# %%
data.drop_duplicates(inplace=True)

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.drop(['Turbo Charger','car model', 'Color', 'Super Charger','No of Doors'], axis=1, inplace=True)

# %%
data.select_dtypes(include='object')
# Out:
#       body type Transmission type Fuel Type     Insurance Validity  \
# 0     Hatchback            Manual    Petrol  Third Party insurance
# 1           SUV            Manual    Petrol          Comprehensive
# 2     Hatchback            Manual    Petrol          Comprehensive
# 3         Sedan            Manual    Petrol          Comprehensive
# 4           SUV            Manual    Diesel  Third Party insurance
# ...         ...               ...       ...                    ...
# 8364  Hatchback            Manual    Petrol  Third Party insurance
# 8365  Hatchback            Manual    Petrol  Third Party insurance
# 8366      Sedan         Automatic    Petrol  Third Party insurance
# 8367  Hatchback            Manual    Petrol  Third Party insurance
# 8368        SUV            Manual    Diesel  Third Party insurance
#
#      Steering Type      City
# 0            Power  Banglore
# 1            Power  Banglore
# 2            Power  Banglore
# 3            Power  Banglore
# 4            Power  Banglore
# ...            ...       ...
# 8364      Electric   Kolkata
# 8365         Power   Kolkata
# 8366         Power   Kolkata
# 8367         Power   Kolkata
# 8368         Power   Kolkata
#
# [8260 rows x 6 columns]

# %%
label_encoders = {}
categorical_columns = ['body type', 'Transmission type', 'Fuel Type', 'Insurance Validity', 'Steering Type', 'City']

for column in categorical_columns:
    le = LabelEncoder()
    data[column] = le.fit_transform(data[column])
    label_encoders[column] = le

# %%
data.head()
# Out:
#    body type  Kilometers driven  Transmission type  Number of owners  \
# 0          2             120000                  1                 3
# 1          7              32706                  1                 2
# 2          2              11949                  1                 1
# 3          8              17794                  1                 1
# 4          7              60000                  1                 1
#
#    Year of manufacture     price  Fuel Type  Insurance Validity  Seats  \
# 0                 2015  400000.0          4                   5    5.0
# 1                 2018  811000.0          4                   0    5.0
# 2                 2018  585000.0          4                   0    5.0
# 3                 2014  462000.0          4                   0    5.0
# 4                 2015  790000.0          1                   5    5.0
#
#    Engine  Mileage  Steering Type  Top Speed  Cargo Volumn  City
# 0   998.0    23.10              4      150.0           235     0
# 1  1497.0    17.00              4      170.0           352     0
# 2  1199.0    23.84              4      150.0           242     0
# 3  1197.0    19.10              4      172.0           407     0
# 4  1248.0    23.65              4      190.0           353     0

# %%
feature_cols = ["Kilometers driven","Number of owners","Year of manufacture","Seats","Engine","Mileage","Cargo Volumn",'City']

# %%
mm_features = MinMaxScaler()
data[feature_cols] = mm_features.fit_transform(data[feature_cols])
mm_price = MinMaxScaler()
data[["price"]] = mm_price.fit_transform(data[["price"]])

# %%
data.head()
# Out:
#    body type  Kilometers driven  Transmission type  Number of owners  \
# 0          2           0.021818                  1               0.6
# 1          7           0.005947                  1               0.4
# 2          2           0.002173                  1               0.2
# 3          8           0.003235                  1               0.2
# 4          7           0.010909                  1               0.2
#
#    Year of manufacture     price  Fuel Type  Insurance Validity  Seats  \
# 0             0.789474  0.009157          4                   5  0.375
# 1             0.868421  0.019066          4                   0  0.375
# 2             0.868421  0.013617          4                   0  0.375
# 3             0.763158  0.010652          4                   0  0.375
# 4             0.789474  0.018559          1                   5  0.375
#
#    Engine   Mileage  Steering Type  Top Speed  Cargo Volumn  City
# 0  0.1996  0.120524              4      150.0      0.000053   0.0
# 1  0.2994  0.074631              4      170.0      0.000084   0.0
# 2  0.2398  0.126091              4      150.0      0.000055   0.0
# 3  0.2394  0.090430              4      172.0      0.000098   0.0
# 4  0.2496  0.124661              4      190.0      0.000084   0.0

# %%
data["City"].value_counts()
# Out:
# City
# 0.4    1471
# 0.6    1464
# 0.0    1463
# 0.2    1409
# 1.0    1361
# 0.8    1092
# Name: count, dtype: int64

# %%
data_corr = data.corr()

# %%
plt.figure(figsize=(20,5))
sns.heatmap(data=data_corr.corr(),annot=True,fmt=".2f",cmap="coolwarm")
plt.show()

# %%
data.columns
# Out:
# Index(['body type', 'Kilometers driven', 'Transmission type',
#        'Number of owners', 'Year of manufacture', 'price', 'Fuel Type',
#        'Insurance Validity', 'Seats', 'Engine', 'Mileage', 'Steering Type',
#        'Top Speed', 'Cargo Volumn', 'City'],
#       dtype='object')

# %%
def get_perform(actual, predict):
    MAE = mean_absolute_error(actual, predict)
    MSE = mean_squared_error(actual, predict)
    MAPE = mean_absolute_percentage_error(actual, predict)
    r2 = r2_score(actual, predict)
    return pd.DataFrame({
        "mean_absolute_error":[MAE],
        "mean_squared_error":[MSE],
        "mean_absolute_percentage_error": [MAPE],
        "r2_score":[r2]
    })

# %%
val = data.drop("price", axis=1)
tar = data["price"]

# %%
train_data, test_data, train_lab, test_lab = train_test_split(val, tar, test_size=0.20, random_state=56)

# %%
# RandomForestRegressor Model

rfr = RandomForestRegressor(n_estimators= 450,max_depth=100,random_state= 35)
rfr.fit(train_data, train_lab)
rfr_train_pred = rfr.predict(train_data)
rfr_test_pred = rfr.predict(test_data)

# %%
get_perform(train_lab, rfr_train_pred)
# Out:
#    mean_absolute_error  mean_squared_error  mean_absolute_percentage_error  \
# 0              0.00137            0.000033                    1.303306e+09
#
#    r2_score
# 0  0.970848

# %%
get_perform(test_lab, rfr_test_pred)
# Out:
#    mean_absolute_error  mean_squared_error  mean_absolute_percentage_error  \
# 0             0.003679            0.000124                        0.166672
#
#    r2_score
# 0  0.910694

# %%
sample_row  = data.loc[[2]].drop('price', axis=1)

# %%
sample_row
# Out:
#    body type  Kilometers driven  Transmission type  Number of owners  \
# 2          2           0.002173                  1               0.2
#
#    Year of manufacture  Fuel Type  Insurance Validity  Seats  Engine  \
# 2             0.868421          4                   0  0.375  0.2398
#
#     Mileage  Steering Type  Top Speed  Cargo Volumn  City
# 2  0.126091              4      150.0      0.000055   0.0

# %%
predicted_scaled = rfr.predict(sample_row)

# %%
predicted_scaled
# Out:
# array([0.01348299])

# %%
predicted_price = mm_price.inverse_transform(predicted_scaled.reshape(-1, 1))

# %%
predicted_price[0][0]
# Out:
# np.float64(579433.3333333326)

# %%
with open("random_forest_model.pkl",'wb') as file:
    pickle.dump(rfr, file)

# %%
with open("minmax_scaler_features.pkl",'wb') as file:
    pickle.dump(mm_features, file)

# %%
with open("minmax_scaler_price.pkl",'wb') as file:
    pickle.dump(mm_price, file)

# %%
with open('label_encoders.pkl', 'wb') as le_file:
    pickle.dump(label_encoders, le_file)
